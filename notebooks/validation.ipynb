# %%
import pandas as pd

df = pd.read_csv("data/processed/state_monthly.csv")

check = (
    df.groupby(["year", "month", "age_group"])["pct_of_india"]
      .sum()
      .reset_index()
)

print(check.head(10))
